# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %%
import os
import os.path as path
import glob 
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Patch
import seaborn as sns
sns.set(font_scale=1.5)
import numpy as np
import pandas as pd
from datetime import datetime
from scipy import stats

# %%
import tools as utils

# %% [markdown]
# ### Defult Path for Input and Target

# %%
wx_data_path  = './DataSciTest/wx_data/'
yld_data_path = './DataSciTest/yld_data/'

# %%
weather_tool = utils.weather_data_tool(wx_data_path, yld_data_path)

# %% [markdown]
# ### Problem 1

# %%
MissingPrcpDataDF = weather_tool.MissingPrcpData() 
MissingPrcpDataDF
# Out:
#             WStation NumMissingPrcpDate
# 0    USC00110072.txt                121
# 1    USC00110187.txt                  6
# 2    USC00110338.txt                 22
# 3    USC00111280.txt                 92
# 4    USC00111436.txt                125
# ..               ...                ...
# 162  USC00338552.txt                  8
# 163  USC00338769.txt                  7
# 164  USC00338822.txt                  9
# 165  USC00338830.txt                201
# 166  USC00339312.txt                  0
#
# [167 rows x 2 columns]

# %% [markdown]
# ### Problem 2

# %%
YearlyAverageDf = weather_tool.YearlyAverages() 
YearlyAverageDf
# Out:
#              WStation  Year  MaxTempAvg  MinTempAvg  TotalAccPrcp
# 0     USC00110072.txt  1985      153.35       43.26          7801
# 1     USC00110072.txt  1986      126.96       21.76          5053
# 2     USC00110072.txt  1987      177.60       63.30          7936
# 3     USC00110072.txt  1988      173.47       45.35          5410
# 4     USC00110072.txt  1989      156.52       39.84          7937
# ...               ...   ...         ...         ...           ...
# 4815  USC00339312.txt  2010      161.68       43.35         10340
# 4816  USC00339312.txt  2011      163.08       50.46         13607
# 4817  USC00339312.txt  2012      177.98       51.65          9108
# 4818  USC00339312.txt  2013      154.74       40.18         10990
# 4819  USC00339312.txt  2014      147.04       28.78          9943
#
# [4820 rows x 5 columns]

# %% [markdown]
# ### Problem 3

# %%
YearHistogramDf = weather_tool.YearHistogram()
YearHistogramDf
# Out:
# The file is already exist!
#     Year YearFreqHighMaxTempAvg YearFreqHighMinTempAvg  \
# 0   1985                      2                      4
# 1   1986                      1                      2
# 2   1987                     13                     17
# 3   1988                      6                      5
# 4   1989                      0                      0
# 5   1990                      2                      2
# 6   1991                      1                      7
# 7   1992                      0                      0
# 8   1993                      0                      1
# 9   1994                      0                      2
# 10  1995                      3                      0
# 11  1996                      0                      0
# 12  1997                      0                      1
# 13  1998                     10                     79
# 14  1999                      6                      3
# 15  2000                      2                      2
# 16  2001                      2                      3
# 17  2002                      1                      1
# 18  2003                      2                      1
# 19  2004                      5                      3
# 20  2005                      2                      3
# 21  2006                      5                      3
# 22  2007                      3                      4
# 23  2008                      4                      2
# 24  2009                      0                      0
# 25  2010                      3                      4
# 26  2011                      2                      5
# 27  2012                     91                      9
# 28  2013                      0                      2
# 29  2014                      1                      2
#
#    YearFreqHighTotalAccPrcp
# 0                         0
# 1                         5
# 2                         1
# 3                         0
# 4                         0
# 5                        23
# 6                         0
# 7                         2
# 8                        38
# 9                         0
# 10                        0
# 11                        6
# 12                        0
# 13                        7
# 14                        1
# 15                        1
# 16                        1
# 17                        0
# 18                        2
# 19                        5
# 20                        0
# 21                        4
# 22                        9
# 23                       11
# 24                        6
# 25                        9
# 26                       35
# 27                        0
# 28                        0
# 29                        1

# %% [markdown]
# ### Problem 4

# %%
CorrelationsDf = weather_tool.Correlations() 
CorrelationsDf
# Out:
# The file is already exist!
#             WStation  PearsonMaxTempYield  PearsonMinTempYield  \
# 0    USC00110072.txt                -0.27                -0.29
# 1    USC00110187.txt                 0.28                 0.11
# 2    USC00110338.txt                -0.30                 0.22
# 3    USC00111280.txt                -0.25                -0.33
# 4    USC00111436.txt                 0.10                 0.01
# ..               ...                  ...                  ...
# 162  USC00338552.txt                -0.09                 0.08
# 163  USC00338769.txt                -0.26                -0.23
# 164  USC00338822.txt                -0.37                -0.37
# 165  USC00338830.txt                -0.27                 0.29
# 166  USC00339312.txt                 0.14                -0.30
#
#      PearsonTtlPrcpYield
# 0                   0.21
# 1                   0.02
# 2                   0.25
# 3                  -0.13
# 4                   0.09
# ..                   ...
# 162                 0.02
# 163                 0.32
# 164                 0.26
# 165                 0.18
# 166                 0.37
#
# [167 rows x 4 columns]
